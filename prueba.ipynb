# %%
import pandas as pd

# %%
df = pd.read_csv(r"archive/Bird Strikes Test.csv")
df
# Out:
# C:\Users\blanc.TORRE-BLANCA\AppData\Local\Temp\ipykernel_7600\4264760907.py:1: DtypeWarning: Columns (7,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"archive/Bird Strikes Test.csv")
#                              Airport: Name Altitude bin Aircraft: Make/Model  \
# 0          DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft                A-319
# 1      DANE COUNTY REGIONAL ARPT-TRUAX FLD    < 1000 ft                A-320
# 2                               HOGUE ARPT    < 1000 ft         PA-46 MALIBU
# 3                          SACRAMENTO INTL    < 1000 ft            B-737-300
# 4                           GUARULHOS INTL    < 1000 ft            B-767-300
# ...                                    ...          ...                  ...
# 65605          CHARLOTTE/DOUGLAS INTL ARPT    < 1000 ft                A-319
# 65606                     KANSAS CITY INTL      Unknown              UNKNOWN
# ...
